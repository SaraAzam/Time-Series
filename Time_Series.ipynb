# %%
import pandas as pd
df=pd.read_csv('/content/aapl.csv')
df.head(2)
type(df.Date[0])#0 means the first column of our data
df = pd.read_csv("aapl.csv",parse_dates=["Date"])
df.head(2)
type(df.Date[0])
df = pd.read_csv("aapl.csv",parse_dates=["Date"], index_col="Date")
df.head(2)
df.index
df['2017-06-21'] # to print the values of specific date
df["2017-01"] # to print the values of specific month
df['2017-06'].head() # to get the top 5 values of specific month
df['2017-06'].Open.mean() # to convert the data days to month on the average bases
df['2017'].head(2) 
df['2017-06-07':'2017-06-03'] # to print the specifc range of observations
df['2017-01']
#  the given data is of days but we want to get of months data than we use resampling
# for month use M and for week use W
df['Close'].resample('W').mean().head()
# to plot the graph
df['Close'].resample('W').mean().plot()
# %matplotlib inline
df['Close'].plot()
df['Close'].resample('M').mean().plot(kind='bar')# for bar diagram
